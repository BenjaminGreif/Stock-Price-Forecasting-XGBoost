# %%
# Core libraries for data handling, date operations, and finance API access
import numpy as np
import yfinance as yf
from datetime import datetime, timedelta
import math
import json
import os
from typing import Dict, Any, Tuple, Optional

# %%
def print_line(symbol: str = "-", length: int = 70) -> None:
    """Print a line of '-' (or symbol) repeated length times."""
    print(symbol * length)

def print_header(title: str) -> None:
    """Surround title with two lines of default separators."""
    print_line()
    print(title)
    print_line()

def compute_profit_metrics(starting_capital: float, final_capital: float) -> Tuple[float, float, float]:
    """
    Compute net profit and percentage change from starting to final capital,
    print a summary, and return (final_capital, profit, profit_percent).
    """
    profit = final_capital - starting_capital
    profit_percent = (profit / starting_capital) * 100
    plus_minus = "+" if profit >= 0 else ""

    print(f"\nInitial Capital: ${starting_capital:,.2f}")
    print(f"Final Capital ${final_capital:,.2f}")
    print(f"Capital Increase: {plus_minus}${profit:,.2f} ({plus_minus}{profit_percent:.2f}%)\n")

    return final_capital, profit, profit_percent

# %%
def fetch_stock_price(ticker: str, date: str) -> float:
    """
    Fetches the stock price for the given ticker from Yahoo Finance on a specific date.
    """
    try:
        # Fetch the stock data
        stock = yf.Ticker(ticker)


        # Get the stock history around the specified date
        stock_info = stock.history(start=date, end="2024-12-15")

        if not stock_info.empty:
            price_on_date = stock_info['Close'].iloc[0]
            return round(price_on_date, 2)
        else:
            raise ValueError(f"No data returned for {ticker} on {date}.")
    except Exception as e:
        print(f"Error fetching stock price for {ticker} on {date}: {e}")
        return None

# %%
def get_first_last_dates(stocks_data: Dict[str, Dict[str, Dict[str, list]]]) -> Tuple[Optional[str], Optional[str]]:
    """
    Return earliest and latest dates (YYYY-MM-DD) in stocks_data, or (None, None) if no dates found.
    """
    all_dates = []
    # Collect all date strings from each group's 'Dates' list
    for groups in stocks_data.values():
        if isinstance(groups, dict):
            for group_data in groups.values():
                if isinstance(group_data, dict) and 'Dates' in group_data:
                    all_dates.extend(group_data['Dates'])
    
    if not all_dates:
        return None, None
    
    # Parse into datetime objects, ignoring invalid formats
    date_objs = []
    for date_str in all_dates:
        try:
            date_objs.append(datetime.strptime(date_str, '%Y-%m-%d'))
        except ValueError as e:
            print(f"Error parsing date '{date_str}': {e}")
    
    if not date_objs:
        return None, None
    
    # Determine earliest and latest
    first_dt = min(date_objs)
    last_dt  = max(date_objs)
    
    return first_dt.strftime('%Y-%m-%d'), last_dt.strftime('%Y-%m-%d')

# %%
def buy_and_hold_all_stocks(
    stocks_data: Dict[str, Any],
    starting_capital: float = 100_000,
    transaction_cost_rate: float = 0.0002
) -> Tuple[float, float, float]:    
    """
    Simulate a realistic buy-and-hold strategy across all stocks:
    
    1. Equally split `starting_capital` across each ticker.
    2. Deduct buy-side fees and invest only the net amount, leaving real cash residue.
    3. Buy on each stock’s first date and sell on its last, applying fees both ways.
    4. Return overall performance metrics: final capital, net profit, and profit %.
    """
    final_capital_per_stock = {}
    total_number_of_stocks = len(stocks_data)
    starting_capital_per_stock = starting_capital / total_number_of_stocks

    for stock, weeks_data in stocks_data.items():
        print(f"\nProcessing stock: {stock}")

        # Get first and last week's data
        first_week = weeks_data[min(weeks_data.keys(), key=int)]['Dates']
        last_week = weeks_data[max(weeks_data.keys(), key=int)]['Dates']
        buying_day = first_week[0]
        selling_day = last_week[-1]

        # Get first and last day's actual prices
        first_day_buy_price = fetch_stock_price(stock, buying_day)
        last_day_sell_price = fetch_stock_price(stock, selling_day)

        if first_day_buy_price is None or last_day_sell_price is None:
            print(f"Skipping {stock} due to missing price data.")
            continue

        # Buy on the first day
        allocated_capital_after_costs = starting_capital_per_stock * (1 - transaction_cost_rate)
        stock_units = int(math.floor(allocated_capital_after_costs / first_day_buy_price))
        print(f"Bought {stock_units} {stock} stock units on the first day {buying_day} at ${first_day_buy_price:.2f}.")

        # Sell on the last day
        final_capital = stock_units * last_day_sell_price * (1 - transaction_cost_rate)
        print(f"Sold {stock_units} {stock} stock units on the last day {selling_day} at ${last_day_sell_price:.2f}. Final Capital: ${final_capital:.2f}")

        final_capital_per_stock[stock] = final_capital

    final_capital_all_stocks = sum(final_capital_per_stock.values())

    return compute_profit_metrics(starting_capital, final_capital_all_stocks)

# %%
def compare_strategies(
    day_trading_results: tuple,
    buy_and_hold_results: tuple,
    dow_jones_index_results: tuple,
    initial_capital: float
) -> None:
    """
    Print a side-by-side performance comparison of three strategies:

    1. Show each strategy’s final capital and percentage return.
    2. Identify the top performer.
    3. Report by how much the best strategy outperformed the others.
    """
    # Unpack the result tuples
    day_final, day_profit, day_pct      = day_trading_results
    hold_final, hold_profit, hold_pct   = buy_and_hold_results
    dj_final, dj_profit, dj_pct         = dow_jones_index_results

    print_header("Performance Evaluation of Investment Strategies...")

    # Initial capital
    print(f"\nInitial Capital: ${initial_capital:,.2f}\n")

    # Aligned summary
    for name, final, profit, pct in [
        ("Trading Bot",     day_final,  day_profit,  day_pct),
        ("Buy and Hold",    hold_final, hold_profit, hold_pct),
        ("Dow Jones Index", dj_final,   dj_profit,   dj_pct),
    ]:
        sign = "+" if pct >= 0 else ""
        # name left-aligned in 20 chars; final in 12 chars; return fixed-width 5 chars
        print(f"{name:<15}  Final Capital: ${final:,.2f}  Return: {sign}{pct:>5.2f}%")

    # Compute outperformance
    returns = {
        "Trading Bot":     day_pct,
        "Buy and Hold":    hold_pct,
        "Dow Jones Index": dj_pct,
    }
    best_name = max(returns, key=returns.get)
    best_pct  = returns[best_name]

    print("\nOutperformance:")
    for name, pct in returns.items():
        if name == best_name:
            continue
        diff = best_pct - pct
        print(f"{best_name:<16} outperformed {name:<15} by {diff:>5.2f}%")

# %%
def trading_bot(
    stocks_data: Dict[str, Dict[str, Dict[str, Any]]],
    starting_capital: float = 100_000,
    transaction_cost_rate: float = 0.0002,
    lookout_window: int = 5,
    max_traded_stocks: int = 1,
    gain_threshold: float = 0.02,
    loss_threshold: float = -0.01
) -> Tuple[float, float, float]:
    """
    Execute a weekly trading strategy over predicted stock data:

    1. At the start of each week, score stocks by their average predicted change
       over the next lookout_window days and buy up to max_traded_stocks top picks.
    2. After at least 3 days, sell holdings if gain ≥ gain_threshold or loss ≤ loss_threshold.
    3. Force-sell any remaining positions at week’s end (day 5) to reset for next week.
    4. Apply transaction_cost_rate to all buys and sells.
    5. Print each trade’s details and return final capital, net profit, and profit percent.
    """

    capital = starting_capital

    # Dictionary to track current holdings:
    # Format: holding_stocks[stock_name] = {
    #   'units': number_of_shares_held,
    #   'buy_price': price_per_share_at_purchase,
    #   'date_bought': date_string (YYYY-MM-DD)
    # }
    holding_stocks = {}

    # Maximum amount to invest in each stock, ensuring diversification and risk management
    max_investment_per_stock = starting_capital * (1 / max_traded_stocks)

    # We find how many weeks there are by looking at the first stock's data length
    total_weeks = len(list(stocks_data.values())[0])

    for week_number in range(1, total_weeks + 1):
        print(f"\nProcessing week {week_number}")

        daily_data = []

        # Gather predictions for each stock for each day in this week
        # We want to find the average and max predicted future price change over the next `lookout_window` days
        for stock, weeks_data in stocks_data.items():
            if str(week_number) in weeks_data:
                week_data = weeks_data[str(week_number)]
                dates = week_data['Dates']
                predicted_changes = week_data['predicted_change']

                for i, date in enumerate(dates):
                    # Extract the next `lookout_window` predicted changes
                    future_preds = predicted_changes[i:i + lookout_window]

                    # Only proceed if we have a full window of future predictions
                    if len(future_preds) == lookout_window:
                        avg_future_prediction = np.mean(future_preds)    # Average predicted change
                        max_future_prediction = max(future_preds)       # Maximum predicted change

                        daily_data.append({
                            'stock': stock,
                            'date': date,
                            'avg_future_prediction': avg_future_prediction,
                            'max_future_prediction': max_future_prediction
                        })

        # Sort the daily_data based on the average future prediction, best (highest) first
        daily_data.sort(key=lambda x: x['avg_future_prediction'], reverse=True)

        # Buy logic: If we are not holding any stocks, consider buying top candidates
        # We only buy if we have capacity (not holding anything) and follow the top predicted stocks
        if not holding_stocks:
            top_stocks = daily_data[:max_traded_stocks]
            for stock_data in top_stocks:
                stock = stock_data['stock']
                date = stock_data['date']

                # Fetch the actual price of the stock on 'date' to simulate a real buy
                buy_price = fetch_stock_price(stock, date)

                # Validate we got a price and have capital to invest
                if buy_price and capital > 1:
                    # Invest up to max_investment_per_stock or the entire capital times (1 - cost) if smaller
                    investment_amount = min(max_investment_per_stock, capital * (1 - transaction_cost_rate))
                    units = investment_amount / buy_price

                    capital -= investment_amount

                    holding_stocks[stock] = {
                        'units': units,
                        'buy_price': buy_price,
                        'date_bought': date
                    }

                    print(f"{date}: Bought {stock}. Units: {units:.2f} at ${buy_price:.2f}. Remaining capital: {capital:.2f}")
                else:
                    print(f"Failed to fetch buy price for {stock} on {date} or insufficient capital. Skipping.")

        # Sell logic: Check existing holdings and decide if we should sell
        # We try to sell after at least 3 days, either because we hit profit/loss thresholds or at the week's end.
        to_sell = []

        for stock, details in holding_stocks.items():
            # Determine the sell date: 3 days after buy date (for initial threshold check)
            buy_date = datetime.strptime(details['date_bought'], "%Y-%m-%d")
            threshold_sell_date = (buy_date + timedelta(days=3)).strftime("%Y-%m-%d")

            sell_price = fetch_stock_price(stock, threshold_sell_date)

            # Calculate gain or loss percentage
            if sell_price:
                gain = (sell_price - details['buy_price']) / details['buy_price']
                plus_minus = "+" if gain >= 0 else ""

                print(f"Checking {stock} on {threshold_sell_date}: Buy Price = ${details['buy_price']:.2f}, "
                      f"Sell Price = ${sell_price:.2f}, Gain = {plus_minus}{gain:.4%}")

                # Decide whether to sell based on thresholds
                if gain >= gain_threshold or gain <= loss_threshold:
                    proceeds = details['units'] * sell_price * (1 - transaction_cost_rate)
                    capital += proceeds
                    print(f"{threshold_sell_date}: Sold {stock} at ${sell_price:.2f}. Capital: {capital:.2f}")
                    to_sell.append(stock)
            else:
                print(f"Failed to fetch sell price for {stock} on {threshold_sell_date}. Retaining holdings for now.")

        # Remove sold stocks from holdings
        for stock in to_sell:
            del holding_stocks[stock]

        # At the end of the week, force sell any remaining holdings that were not sold earlier
        # This ensures we do not carry the same holdings into the next week indefinitely.
        to_remove = []

        for stock in list(holding_stocks.keys()):
            details = holding_stocks[stock]
            # The forced sell date: 5 days after the buy date
            forced_sell_date = datetime.strptime(details['date_bought'], "%Y-%m-%d") + timedelta(days=5)
            forced_sell_date_str = forced_sell_date.strftime("%Y-%m-%d")

            sell_price = fetch_stock_price(stock, forced_sell_date_str)

            if sell_price:
                # Sell at forced date regardless of gain/loss
                proceeds = details['units'] * sell_price * (1 - transaction_cost_rate)
                capital += proceeds
                print(f"End of week: Forced sell of {stock} at ${sell_price:.2f}. Capital: {capital:.2f}")
                to_remove.append(stock)
            else:
                print(f"End of week: Failed to fetch price for {stock} on {forced_sell_date_str}. Retaining holdings.")

        # Remove the forcibly sold stocks from holdings
        for stock in to_remove:
            del holding_stocks[stock]

    # Attempt to sell any remaining holdings at the final forced date.
    for stock, details in holding_stocks.items():
        final_sell_date = datetime.strptime(details['date_bought'], "%Y-%m-%d") + timedelta(days=5)
        final_sell_date_str = final_sell_date.strftime("%Y-%m-%d")

        sell_price = fetch_stock_price(stock, final_sell_date_str)

        if sell_price:
            # Sell whatever is left at the final cleanup
            proceeds = details['units'] * sell_price * (1 - transaction_cost_rate)
            capital += proceeds
            print(f"Final Sell: {stock} at ${sell_price:.2f}. Capital: {capital:.2f}")
        else:
            print(f"Failed to fetch final price for {stock}. Retaining holdings. Capital remains ${capital:.2f}")

    return compute_profit_metrics(starting_capital, capital)

# %%
def buy_and_hold_index(
    ticker: str,
    stocks_data: Dict[str, Any],
    starting_capital: float = 100_000,
    transaction_cost_rate: float = 0.0002
) -> Tuple[float, float, float]:
    """
    Simulate a buy-and-hold strategy for an index ticker using fractional shares:

    1. Determine the overall date range via get_first_last_dates().
    2. Fetch the index’s closing price on the first and last dates.
    3. Invest the entire starting_capital net of the buy-side fee.
    4. Sell all fractional shares at the end date net of the sell-side fee.
    5. Return (final_capital, profit, profit_percent) via compute_profit_metrics().
    """
    # Fetch only the two required prices
    start_date, end_date = get_first_last_dates(stocks_data)
    first_day_buy_price = fetch_stock_price(ticker, start_date)
    last_day_buy_price  = fetch_stock_price(ticker, end_date)

    if first_day_buy_price is None or last_day_buy_price is None:
        raise ValueError(f"Error fetching price for {ticker} on {start_date} or {end_date}")

    # Deduct buy-side fee and invest all remaining capital fractionally
    capital_after_buy_fee = starting_capital * (1 - transaction_cost_rate)
    stock_units = capital_after_buy_fee / first_day_buy_price

    # On sell, apply sell-side fee to all proceeds
    sale_proceeds = stock_units * last_day_buy_price * (1 - transaction_cost_rate)
    final_capital = sale_proceeds

    return compute_profit_metrics(starting_capital, final_capital)

# %%
def main():
    """
    Orchestrate end-to-end strategy simulations and comparison:

    1. Load stock prediction data from JSON.
    2. Initialize starting capital.
    3. Run the smart trading bot.
    4. Run buy-and-hold across individual stocks.
    5. Run buy-and-hold for the Dow Jones Index.
    6. Compare and report on all strategies’ performance.
    """
    # 1) Load stock predictions from JSON file
    file_path = 'stock_sample_predictions_52_weeks.json'
    try:
        with open(file_path, 'r') as file:
            stocks_data = json.load(file)
    except FileNotFoundError:
        raise RuntimeError(f"Could not find data file at {file_path}")

    # 2) Set up initial capital for all simulations
    initial_capital = 100_000

    # 3) Run the smart trading bot simulation
    print_header("Running Trading Bot...")
    day_trading_results = trading_bot(
        stocks_data,
        starting_capital=initial_capital,
        max_traded_stocks=2,
        gain_threshold=0.7,
        loss_threshold=-0.07
    )

    # 4) Run the buy-and-hold simulation across all stocks
    print_header("Running Buy and Hold Strategy...")
    buy_and_hold_results = buy_and_hold_all_stocks(
        stocks_data,
        starting_capital=initial_capital
    )

    # 5) Run the buy-and-hold simulation for the Dow Jones Index
    print_header("Running Dow Jones Index Strategy...")
    dow_jones_index_results = buy_and_hold_index(
        '^DJI',
        stocks_data,
        starting_capital=initial_capital
    )

    # 6) Compare and report on the performance of all strategies
    compare_strategies(
        day_trading_results,
        buy_and_hold_results,
        dow_jones_index_results,
        initial_capital
    )

if __name__ == "__main__":
    main()
# Out:
# ----------------------------------------------------------------------
# Running Trading Bot...
# ----------------------------------------------------------------------
#
# Processing week 1
# 2023-11-21: Bought AMZN. Units: 347.46 at $143.90. Remaining capital: 50000.00
# 2023-11-21: Bought IBM. Units: 341.04 at $146.58. Remaining capital: 10.00
# Checking AMZN on 2023-11-24: Buy Price = $143.90, Sell Price = $146.74, Gain = +1.9736%
# Checking IBM on 2023-11-24: Buy Price = $146.58, Sell Price = $147.79, Gain = +0.8255%
# End of week: Forced sell of AMZN at $147.73. Capital: 51330.52
# End of week: Forced sell of IBM at $148.16. Capital: 101849.26
#
# Processing week 2
# 2023-11-29: Bought TSLA. Units: 204.80 at $244.14. Remaining capital: 51849.26
# 2023-12-05: Bought SIE.DE. Units: 331.52 at $150.82. Remaining capital: 1849.26
# Checking TSLA on 2023-12-02: Buy Price = $244.14, Sell Price = $235.58, Gain = -3.5062%
# Checking SIE.DE on 2023-12-08: Buy Price = $150.82, Sell Price = $154.31, Gain = +2.3140%
# End of week: Forced sell of TSLA at $235.58. Capital: 50086.52
# End of week: Forced sell of SIE.DE at $156.10. Capital: 101826.60
#
# Processing week 3
# 2023-12-06: Bought AMZN. Units: 345.97 at $144.52. Remaining capital: 51826.60
# 2023-12-12: Bought SIE.DE. Units: 321.17 at $155.68. Remaining capital: 1826.60
# Checking AMZN on 2023-12-09: Buy Price = $144.52, Sell Price = $145.89, Gain = +0.9480%
# Checking SIE.DE on 2023-12-15: Buy Price = $155.68, Sell Price = $158.46, Gain = +1.7857%
# End of week: Forced sell of AMZN at $145.89. Capital: 52290.49
# End of week: Forced sell of SIE.DE at $155.24. Capital: 102139.20
#
# Processing week 4
# 2023-12-13: Bought AMZN. Units: 335.93 at $148.84. Remaining capital: 52139.20
# 2023-12-13: Bought V. Units: 192.66 at $259.52. Remaining capital: 2139.20
# Checking AMZN on 2023-12-16: Buy Price = $148.84, Sell Price = $154.07, Gain = +3.5138%
# Checking V on 2023-12-16: Buy Price = $259.52, Sell Price = $255.55, Gain = -1.5297%
# End of week: Forced sell of AMZN at $154.07. Capital: 53885.77
# End of week: Forced sell of V at $255.55. Capital: 103111.05
#
# Processing week 5
# 2023-12-20: Bought TSLA. Units: 202.31 at $247.14. Remaining capital: 53111.05
# 2023-12-28: Bought SIE.DE. Units: 312.36 at $160.07. Remaining capital: 3111.05
# Checking TSLA on 2023-12-23: Buy Price = $247.14, Sell Price = $256.61, Gain = +3.8318%
# Checking SIE.DE on 2023-12-31: Buy Price = $160.07, Sell Price = $159.50, Gain = -0.3561%
# End of week: Forced sell of TSLA at $256.61. Capital: 55016.58
# End of week: Forced sell of SIE.DE at $159.50. Capital: 104828.57
#
# Processing week 6
# 2023-12-28: Bought TSLA. Units: 197.49 at $253.18. Remaining capital: 54828.57
# 2024-01-05: Bought MUV2.DE. Units: 134.78 at $370.97. Remaining capital: 4828.57
# Checking TSLA on 2023-12-31: Buy Price = $253.18, Sell Price = $248.42, Gain = -1.8801%
# Checking MUV2.DE on 2024-01-08: Buy Price = $370.97, Sell Price = $369.42, Gain = -0.4178%
# End of week: Forced sell of TSLA at $248.42. Capital: 53878.72
# End of week: Forced sell of MUV2.DE at $366.15. Capital: 103219.20
#
# Processing week 7
# 2024-01-05: Bought V. Units: 194.66 at $256.86. Remaining capital: 53219.20
# 2024-01-05: Bought IBM. Units: 329.86 at $151.58. Remaining capital: 3219.20
# Checking V on 2024-01-08: Buy Price = $256.86, Sell Price = $259.68, Gain = +1.0979%
# Checking IBM on 2024-01-08: Buy Price = $151.58, Sell Price = $153.47, Gain = +1.2469%
# End of week: Forced sell of V at $261.68. Capital: 54147.27
# End of week: Forced sell of IBM at $153.55. Capital: 104786.96
#
# Processing week 8
# 2024-01-12: Bought AMZN. Units: 323.37 at $154.62. Remaining capital: 54786.96
# 2024-01-19: Bought SIE.DE. Units: 326.99 at $152.91. Remaining capital: 4786.96
# Checking AMZN on 2024-01-15: Buy Price = $154.62, Sell Price = $153.16, Gain = -0.9443%
# Checking SIE.DE on 2024-01-22: Buy Price = $152.91, Sell Price = $155.24, Gain = +1.5238%
# End of week: Forced sell of AMZN at $151.71. Capital: 53836.13
# End of week: Forced sell of SIE.DE at $159.14. Capital: 105862.87
#
# Processing week 9
# 2024-01-22: Bought AMZN. Units: 323.04 at $154.78. Remaining capital: 55862.87
# 2024-01-22: Bought IBM. Units: 303.77 at $164.60. Remaining capital: 5862.87
# Checking AMZN on 2024-01-25: Buy Price = $154.78, Sell Price = $157.75, Gain = +1.9189%
# Checking IBM on 2024-01-25: Buy Price = $164.60, Sell Price = $181.36, Gain = +10.1823%
# End of week: Forced sell of AMZN at $161.26. Capital: 57945.74
# End of week: Forced sell of IBM at $178.23. Capital: 112075.25
#
# Processing week 10
# 2024-01-29: Bought AMZN. Units: 310.06 at $161.26. Remaining capital: 62075.25
# 2024-01-29: Bought KO. Units: 868.96 at $57.54. Remaining capital: 12075.25
# Checking AMZN on 2024-02-01: Buy Price = $161.26, Sell Price = $159.28, Gain = -1.2278%
# Checking KO on 2024-02-01: Buy Price = $57.54, Sell Price = $58.74, Gain = +2.0855%
# End of week: Forced sell of AMZN at $170.31. Capital: 64870.72
# End of week: Forced sell of KO at $57.83. Capital: 115112.67
#
# Processing week 11
# 2024-02-05: Bought AMZN. Units: 293.58 at $170.31. Remaining capital: 65112.67
# 2024-02-09: Bought SIE.DE. Units: 309.14 at $161.74. Remaining capital: 15112.67
# Checking AMZN on 2024-02-08: Buy Price = $170.31, Sell Price = $169.84, Gain = -0.2760%
# Checking SIE.DE on 2024-02-12: Buy Price = $161.74, Sell Price = $161.36, Gain = -0.2349%
# End of week: Forced sell of AMZN at $172.34. Capital: 65698.52
# End of week: Forced sell of SIE.DE at $161.27. Capital: 115543.26
#
# Processing week 12
# 2024-02-12: Bought AMZN. Units: 290.12 at $172.34. Remaining capital: 65543.26
# 2024-02-12: Bought IBM. Units: 279.47 at $178.91. Remaining capital: 15543.26
# Checking AMZN on 2024-02-15: Buy Price = $172.34, Sell Price = $169.80, Gain = -1.4738%
# Checking IBM on 2024-02-15: Buy Price = $178.91, Sell Price = $179.60, Gain = +0.3857%
# End of week: Forced sell of AMZN at $167.08. Capital: 64007.51
# End of week: Forced sell of IBM at $176.30. Capital: 113268.24
#
# Processing week 13
# 2024-02-23: Bought SIE.DE. Units: 291.90 at $171.29. Remaining capital: 63268.24
# 2024-02-23: Bought MUV2.DE. Units: 122.43 at $408.39. Remaining capital: 13268.24
# Checking SIE.DE on 2024-02-26: Buy Price = $171.29, Sell Price = $170.90, Gain = -0.2277%
# Checking MUV2.DE on 2024-02-26: Buy Price = $408.39, Sell Price = $406.56, Gain = -0.4481%
# End of week: Forced sell of SIE.DE at $175.75. Capital: 64559.86
# End of week: Forced sell of MUV2.DE at $409.74. Capital: 114715.11
#
# Processing week 14
# 2024-03-01: Bought SIE.DE. Units: 282.26 at $177.14. Remaining capital: 64715.11
# 2024-02-27: Bought TSLA. Units: 250.34 at $199.73. Remaining capital: 14715.11
# Checking SIE.DE on 2024-03-04: Buy Price = $177.14, Sell Price = $176.94, Gain = -0.1129%
# Checking TSLA on 2024-03-01: Buy Price = $199.73, Sell Price = $202.64, Gain = +1.4570%
# End of week: Forced sell of SIE.DE at $175.88. Capital: 64349.53
# End of week: Forced sell of TSLA at $188.14. Capital: 111438.70
#
# Processing week 15
# 2024-03-05: Bought IBM. Units: 271.03 at $184.48. Remaining capital: 61438.70
# 2024-03-08: Bought SIE.DE. Units: 281.28 at $177.76. Remaining capital: 11438.70
# Checking IBM on 2024-03-08: Buy Price = $184.48, Sell Price = $188.32, Gain = +2.0815%
# Checking SIE.DE on 2024-03-11: Buy Price = $177.76, Sell Price = $176.49, Gain = -0.7144%
# End of week: Forced sell of IBM at $184.27. Capital: 61371.79
# End of week: Forced sell of SIE.DE at $179.70. Capital: 111907.36
#
# Processing week 16
# 2024-03-15: Bought MUV2.DE. Units: 116.28 at $430.00. Remaining capital: 61907.36
# 2024-03-12: Bought KO. Units: 857.93 at $58.28. Remaining capital: 11907.36
# Checking MUV2.DE on 2024-03-18: Buy Price = $430.00, Sell Price = $430.00, Gain = +0.0000%
# Checking KO on 2024-03-15: Buy Price = $58.28, Sell Price = $58.14, Gain = -0.2402%
# End of week: Forced sell of MUV2.DE at $432.12. Capital: 62143.82
# End of week: Forced sell of KO at $58.38. Capital: 112219.60
#
# Processing week 17
# 2024-03-19: Bought TSLA. Units: 291.85 at $171.32. Remaining capital: 62219.60
# 2024-03-22: Bought BAS.DE. Units: 1070.43 at $46.71. Remaining capital: 12219.60
# Checking TSLA on 2024-03-22: Buy Price = $171.32, Sell Price = $170.83, Gain = -0.2860%
# Checking BAS.DE on 2024-03-25: Buy Price = $46.71, Sell Price = $46.90, Gain = +0.4068%
# End of week: Forced sell of TSLA at $172.63. Capital: 62591.85
# End of week: Forced sell of BAS.DE at $47.18. Capital: 113084.85
#
# Processing week 18
# 2024-03-26: Bought AMZN. Units: 280.43 at $178.30. Remaining capital: 63084.85
# 2024-04-02: Bought MUV2.DE. Units: 114.94 at $435.01. Remaining capital: 13084.85
# Checking AMZN on 2024-03-29: Buy Price = $178.30, Sell Price = $180.97, Gain = +1.4975%
# Checking MUV2.DE on 2024-04-05: Buy Price = $435.01, Sell Price = $409.36, Gain = -5.8964%
# End of week: Forced sell of AMZN at $180.97. Capital: 63823.44
# End of week: Forced sell of MUV2.DE at $411.38. Capital: 111097.95
#
# Processing week 19
# 2024-04-09: Bought SIE.DE. Units: 295.54 at $169.18. Remaining capital: 61097.95
# 2024-04-09: Bought MUV2.DE. Units: 125.33 at $398.94. Remaining capital: 11097.95
# Checking SIE.DE on 2024-04-12: Buy Price = $169.18, Sell Price = $168.71, Gain = -0.2778%
# Checking MUV2.DE on 2024-04-12: Buy Price = $398.94, Sell Price = $400.87, Gain = +0.4838%
# End of week: Forced sell of SIE.DE at $171.88. Capital: 61885.76
# End of week: Forced sell of MUV2.DE at $404.34. Capital: 112552.42
#
# Processing week 20
# 2024-04-16: Bought SIE.DE. Units: 295.65 at $169.12. Remaining capital: 62552.42
# 2024-04-16: Bought MUV2.DE. Units: 126.13 at $396.43. Remaining capital: 12552.42
# Checking SIE.DE on 2024-04-19: Buy Price = $169.12, Sell Price = $169.01, Gain = -0.0650%
# Checking MUV2.DE on 2024-04-19: Buy Price = $396.43, Sell Price = $400.29, Gain = +0.9737%
# End of week: Forced sell of SIE.DE at $170.04. Capital: 62814.36
# End of week: Forced sell of MUV2.DE at $403.67. Capital: 113717.33
#
# Processing week 21
# 2024-04-17: Bought IBM. Units: 284.14 at $175.97. Remaining capital: 63717.33
# 2024-04-23: Bought MUV2.DE. Units: 119.17 at $419.58. Remaining capital: 13717.33
# Checking IBM on 2024-04-20: Buy Price = $175.97, Sell Price = $174.82, Gain = -0.6535%
# Checking MUV2.DE on 2024-04-26: Buy Price = $419.58, Sell Price = $413.50, Gain = -1.4491%
# End of week: Forced sell of IBM at $174.82. Capital: 63380.63
# End of week: Forced sell of MUV2.DE at $414.30. Capital: 112741.56
#
# Processing week 22
# 2024-04-24: Bought AMZN. Units: 283.14 at $176.59. Remaining capital: 62741.56
# 2024-04-24: Bought V. Units: 183.47 at $272.53. Remaining capital: 12741.56
# Checking AMZN on 2024-04-27: Buy Price = $176.59, Sell Price = $180.96, Gain = +2.4747%
# Checking V on 2024-04-27: Buy Price = $272.53, Sell Price = $269.38, Gain = -1.1558%
# End of week: Forced sell of AMZN at $180.96. Capital: 63968.64
# End of week: Forced sell of V at $269.38. Capital: 113380.84
#
# Processing week 23
# 2024-05-08: Bought MUV2.DE. Units: 115.37 at $433.40. Remaining capital: 63380.84
# 2024-05-08: Bought BAS.DE. Units: 1063.83 at $47.00. Remaining capital: 13380.84
# Checking MUV2.DE on 2024-05-11: Buy Price = $433.40, Sell Price = $447.50, Gain = +3.2533%
# Checking BAS.DE on 2024-05-11: Buy Price = $47.00, Sell Price = $46.55, Gain = -0.9574%
# End of week: Forced sell of MUV2.DE at $447.50. Capital: 64997.19
# End of week: Forced sell of BAS.DE at $46.55. Capital: 114508.56
#
# Processing week 24
# 2024-05-08: Bought V. Units: 182.03 at $274.68. Remaining capital: 64508.56
# 2024-05-15: Bought VOW3.DE. Units: 475.38 at $105.18. Remaining capital: 14508.56
# Checking V on 2024-05-11: Buy Price = $274.68, Sell Price = $276.86, Gain = +0.7937%
# Checking VOW3.DE on 2024-05-18: Buy Price = $105.18, Sell Price = $103.44, Gain = -1.6543%
# End of week: Forced sell of V at $276.86. Capital: 64895.30
# End of week: Forced sell of VOW3.DE at $103.44. Capital: 114058.32
#
# Processing week 25
# 2024-05-22: Bought MUV2.DE. Units: 108.34 at $461.50. Remaining capital: 64058.32
# 2024-05-15: Bought TSLA. Units: 287.37 at $173.99. Remaining capital: 14058.32
# Checking MUV2.DE on 2024-05-25: Buy Price = $461.50, Sell Price = $462.50, Gain = +0.2167%
# Checking TSLA on 2024-05-18: Buy Price = $173.99, Sell Price = $174.95, Gain = +0.5518%
# End of week: Forced sell of MUV2.DE at $462.50. Capital: 64156.64
# End of week: Forced sell of TSLA at $174.95. Capital: 114422.46
#
# Processing week 26
# 2024-05-22: Bought TSLA. Units: 277.61 at $180.11. Remaining capital: 64422.46
# 2024-05-22: Bought IBM. Units: 296.58 at $168.59. Remaining capital: 14422.46
# Checking TSLA on 2024-05-25: Buy Price = $180.11, Sell Price = $176.75, Gain = -1.8655%
# Checking IBM on 2024-05-25: Buy Price = $168.59, Sell Price = $164.67, Gain = -2.3252%
# End of week: Forced sell of TSLA at $176.75. Capital: 63479.88
# End of week: Forced sell of IBM at $164.67. Capital: 112307.53
#
# Processing week 27
# 2024-05-30: Bought KO. Units: 830.98 at $60.17. Remaining capital: 62307.53
# 2024-06-05: Bought BAYN.DE. Units: 1756.85 at $28.46. Remaining capital: 12307.53
# Checking KO on 2024-06-02: Buy Price = $60.17, Sell Price = $61.10, Gain = +1.5456%
# Checking BAYN.DE on 2024-06-08: Buy Price = $28.46, Sell Price = $27.34, Gain = -3.9353%
# End of week: Forced sell of KO at $62.08. Capital: 63884.38
# End of week: Forced sell of BAYN.DE at $27.34. Capital: 111907.10
#
# Processing week 28
# 2024-06-06: Bought AMZN. Units: 270.27 at $185.00. Remaining capital: 61907.10
# 2024-06-06: Bought IBM. Units: 306.26 at $163.26. Remaining capital: 11907.10
# Checking AMZN on 2024-06-09: Buy Price = $185.00, Sell Price = $187.06, Gain = +1.1135%
# Checking IBM on 2024-06-09: Buy Price = $163.26, Sell Price = $165.37, Gain = +1.2924%
# End of week: Forced sell of AMZN at $187.23. Capital: 62499.69
# End of week: Forced sell of IBM at $164.34. Capital: 112820.38
#
# Processing week 29
# 2024-06-13: Bought TSLA. Units: 274.02 at $182.47. Remaining capital: 62820.38
# 2024-06-19: Bought MUV2.DE. Units: 108.48 at $460.90. Remaining capital: 12820.38
# Checking TSLA on 2024-06-16: Buy Price = $182.47, Sell Price = $187.44, Gain = +2.7237%
# Checking MUV2.DE on 2024-06-22: Buy Price = $460.90, Sell Price = $467.10, Gain = +1.3452%
# End of week: Forced sell of TSLA at $184.86. Capital: 63465.15
# End of week: Forced sell of MUV2.DE at $467.10. Capital: 114127.61
#
# Processing week 30
# 2024-06-21: Bought AMZN. Units: 264.44 at $189.08. Remaining capital: 64127.61
# 2024-06-21: Bought IBM. Units: 298.70 at $167.39. Remaining capital: 14127.61
# Checking AMZN on 2024-06-24: Buy Price = $189.08, Sell Price = $185.57, Gain = -1.8564%
# Checking IBM on 2024-06-24: Buy Price = $167.39, Sell Price = $169.87, Gain = +1.4816%
# End of week: Forced sell of AMZN at $193.61. Capital: 65315.28
# End of week: Forced sell of IBM at $166.82. Capital: 115135.05
#
# Processing week 31
# 2024-06-28: Bought AMZN. Units: 258.73 at $193.25. Remaining capital: 65135.05
# 2024-07-03: Bought BAS.DE. Units: 1163.87 at $42.96. Remaining capital: 15135.05
# Checking AMZN on 2024-07-01: Buy Price = $193.25, Sell Price = $197.20, Gain = +2.0440%
# Checking BAS.DE on 2024-07-06: Buy Price = $42.96, Sell Price = $42.67, Gain = -0.6750%
# End of week: Forced sell of AMZN at $197.59. Capital: 66247.73
# End of week: Forced sell of BAS.DE at $42.67. Capital: 115900.27
#
# Processing week 32
# 2024-07-08: Bought AMZN. Units: 250.89 at $199.29. Remaining capital: 65900.27
# 2024-07-08: Bought TSLA. Units: 197.68 at $252.94. Remaining capital: 15900.27
# Checking AMZN on 2024-07-11: Buy Price = $199.29, Sell Price = $195.05, Gain = -2.1276%
# Checking TSLA on 2024-07-11: Buy Price = $252.94, Sell Price = $241.03, Gain = -4.7086%
# End of week: Forced sell of AMZN at $192.72. Capital: 64242.25
# End of week: Forced sell of TSLA at $252.64. Capital: 114172.96
#
# Processing week 33
# 2024-07-15: Bought TSLA. Units: 197.91 at $252.64. Remaining capital: 64172.96
# 2024-07-15: Bought IBM. Units: 281.67 at $177.51. Remaining capital: 14172.96
# Checking TSLA on 2024-07-18: Buy Price = $252.64, Sell Price = $249.23, Gain = -1.3497%
# Checking IBM on 2024-07-18: Buy Price = $177.51, Sell Price = $179.78, Gain = +1.2788%
# End of week: Forced sell of TSLA at $251.51. Capital: 63939.36
# End of week: Forced sell of IBM at $178.74. Capital: 114275.75
#
# Processing week 34
# 2024-07-24: Bought MUV2.DE. Units: 110.99 at $450.50. Remaining capital: 64275.75
# 2024-07-24: Bought SIE.DE. Units: 298.47 at $167.52. Remaining capital: 14275.75
# Checking MUV2.DE on 2024-07-27: Buy Price = $450.50, Sell Price = $451.30, Gain = +0.1776%
# Checking SIE.DE on 2024-07-27: Buy Price = $167.52, Sell Price = $164.00, Gain = -2.1012%
# End of week: Forced sell of MUV2.DE at $451.30. Capital: 64354.53
# End of week: Forced sell of SIE.DE at $164.00. Capital: 113294.12
#
# Processing week 35
# 2024-07-29: Bought AMZN. Units: 272.93 at $183.20. Remaining capital: 63294.12
# 2024-07-29: Bought V. Units: 192.52 at $259.71. Remaining capital: 13294.12
# Checking AMZN on 2024-08-01: Buy Price = $183.20, Sell Price = $184.07, Gain = +0.4749%
# Checking V on 2024-08-01: Buy Price = $259.71, Sell Price = $264.01, Gain = +1.6557%
# End of week: Forced sell of AMZN at $161.02. Capital: 57231.83
# End of week: Forced sell of V at $254.59. Capital: 106236.32
#
# Processing week 36
# 2024-08-05: Bought KO. Units: 750.30 at $66.64. Remaining capital: 56236.32
# 2024-08-05: Bought V. Units: 196.39 at $254.59. Remaining capital: 6236.32
# Checking KO on 2024-08-08: Buy Price = $66.64, Sell Price = $67.25, Gain = +0.9154%
# Checking V on 2024-08-08: Buy Price = $254.59, Sell Price = $257.95, Gain = +1.3198%
# End of week: Forced sell of KO at $66.70. Capital: 56271.32
# End of week: Forced sell of V at $258.53. Capital: 107034.96
#
# Processing week 37
# 2024-08-14: Bought SIE.DE. Units: 321.21 at $155.66. Remaining capital: 57034.96
# 2024-08-12: Bought AMZN. Units: 299.76 at $166.80. Remaining capital: 7034.96
# Checking SIE.DE on 2024-08-17: Buy Price = $155.66, Sell Price = $160.50, Gain = +3.1093%
# Checking AMZN on 2024-08-15: Buy Price = $166.80, Sell Price = $177.59, Gain = +6.4688%
# End of week: Forced sell of SIE.DE at $160.50. Capital: 58579.32
# End of week: Forced sell of AMZN at $178.22. Capital: 111991.90
#
# Processing week 38
# 2024-08-19: Bought KO. Units: 740.74 at $67.50. Remaining capital: 61991.90
# 2024-08-21: Bought MUV2.DE. Units: 107.41 at $465.50. Remaining capital: 11991.90
# Checking KO on 2024-08-22: Buy Price = $67.50, Sell Price = $67.84, Gain = +0.5037%
# Checking MUV2.DE on 2024-08-24: Buy Price = $465.50, Sell Price = $474.90, Gain = +2.0193%
# End of week: Forced sell of KO at $69.32. Capital: 63329.78
# End of week: Forced sell of MUV2.DE at $474.90. Capital: 114329.24
#
# Processing week 39
# 2024-08-26: Bought TSLA. Units: 234.51 at $213.21. Remaining capital: 64329.24
# 2024-08-26: Bought AMZN. Units: 284.90 at $175.50. Remaining capital: 14329.24
# Checking TSLA on 2024-08-29: Buy Price = $213.21, Sell Price = $206.28, Gain = -3.2503%
# Checking AMZN on 2024-08-29: Buy Price = $175.50, Sell Price = $172.12, Gain = -1.9259%
# End of week: Forced sell of TSLA at $210.60. Capital: 63707.29
# End of week: Forced sell of AMZN at $176.25. Capital: 113910.92
#
# Processing week 40
# 2024-09-03: Bought AMZN. Units: 283.69 at $176.25. Remaining capital: 63910.92
# 2024-09-03: Bought TSLA. Units: 237.42 at $210.60. Remaining capital: 13910.92
# Checking AMZN on 2024-09-06: Buy Price = $176.25, Sell Price = $171.39, Gain = -2.7574%
# Checking TSLA on 2024-09-06: Buy Price = $210.60, Sell Price = $210.73, Gain = +0.0617%
# End of week: Forced sell of AMZN at $175.40. Capital: 63659.84
# End of week: Forced sell of TSLA at $216.27. Capital: 114995.72
#
# Processing week 41
# 2024-09-10: Bought AMZN. Units: 278.47 at $179.55. Remaining capital: 64995.72
# 2024-09-10: Bought V. Units: 176.15 at $283.85. Remaining capital: 14995.72
# Checking AMZN on 2024-09-13: Buy Price = $179.55, Sell Price = $186.49, Gain = +3.8652%
# Checking V on 2024-09-13: Buy Price = $283.85, Sell Price = $285.85, Gain = +0.7046%
# End of week: Forced sell of AMZN at $184.89. Capital: 66472.48
# End of week: Forced sell of V at $288.96. Capital: 117362.42
#
# Processing week 42
# 2024-09-18: Bought SIE.DE. Units: 308.78 at $161.93. Remaining capital: 67362.42
# 2024-09-17: Bought IBM. Units: 238.49 at $209.65. Remaining capital: 17362.42
# Checking SIE.DE on 2024-09-21: Buy Price = $161.93, Sell Price = $163.67, Gain = +1.0745%
# Checking IBM on 2024-09-20: Buy Price = $209.65, Sell Price = $213.15, Gain = +1.6694%
# End of week: Forced sell of SIE.DE at $163.67. Capital: 67889.58
# End of week: Forced sell of IBM at $215.89. Capital: 119367.48
#
# Processing week 43
# 2024-09-24: Bought AMZN. Units: 257.79 at $193.96. Remaining capital: 69367.48
# 2024-09-25: Bought SIE.DE. Units: 296.56 at $168.60. Remaining capital: 19367.48
# Checking AMZN on 2024-09-27: Buy Price = $193.96, Sell Price = $187.97, Gain = -3.0883%
# Checking SIE.DE on 2024-09-28: Buy Price = $168.60, Sell Price = $177.19, Gain = +5.0949%
# End of week: Forced sell of AMZN at $186.33. Capital: 67390.97
# End of week: Forced sell of SIE.DE at $177.19. Capital: 119927.91
#
# Processing week 44
# 2024-10-01: Bought TSLA. Units: 193.78 at $258.02. Remaining capital: 69927.91
# 2024-10-01: Bought IBM. Units: 232.81 at $214.77. Remaining capital: 19927.91
# Checking TSLA on 2024-10-04: Buy Price = $258.02, Sell Price = $250.08, Gain = -3.0773%
# Checking IBM on 2024-10-04: Buy Price = $214.77, Sell Price = $221.28, Gain = +3.0311%
# End of week: Forced sell of TSLA at $240.83. Capital: 66587.44
# End of week: Forced sell of IBM at $222.37. Capital: 118346.42
#
# Processing week 45
# 2024-10-09: Bought MUV2.DE. Units: 104.19 at $479.90. Remaining capital: 68346.42
# 2024-10-08: Bought IBM. Units: 223.37 at $223.84. Remaining capital: 18346.42
# Checking MUV2.DE on 2024-10-12: Buy Price = $479.90, Sell Price = $505.00, Gain = +5.2303%
# Checking IBM on 2024-10-11: Buy Price = $223.84, Sell Price = $228.38, Gain = +2.0282%
# End of week: Forced sell of MUV2.DE at $505.00. Capital: 70951.03
# End of week: Forced sell of IBM at $230.34. Capital: 122392.67
#
# Processing week 46
# 2024-10-16: Bought MUV2.DE. Units: 98.81 at $506.00. Remaining capital: 72392.67
# 2024-10-15: Bought IBM. Units: 219.21 at $228.09. Remaining capital: 22392.67
# Checking MUV2.DE on 2024-10-19: Buy Price = $506.00, Sell Price = $490.30, Gain = -3.1028%
# Checking IBM on 2024-10-18: Buy Price = $228.09, Sell Price = $227.35, Gain = -0.3244%
# End of week: Forced sell of MUV2.DE at $490.30. Capital: 70831.59
# End of week: Forced sell of IBM at $226.91. Capital: 120562.97
#
# Processing week 47
# 2024-10-23: Bought VOW3.DE. Units: 585.89 at $85.34. Remaining capital: 70562.97
# 2024-10-23: Bought BAYN.DE. Units: 1960.78 at $25.50. Remaining capital: 20562.97
# Checking VOW3.DE on 2024-10-26: Buy Price = $85.34, Sell Price = $86.18, Gain = +0.9843%
# Checking BAYN.DE on 2024-10-26: Buy Price = $25.50, Sell Price = $25.98, Gain = +1.8824%
# End of week: Forced sell of VOW3.DE at $86.18. Capital: 71045.03
# End of week: Forced sell of BAYN.DE at $25.98. Capital: 121976.01
#
# Processing week 48
# 2024-10-29: Bought V. Units: 178.31 at $280.41. Remaining capital: 71976.01
# 2024-10-29: Bought AMZN. Units: 262.01 at $190.83. Remaining capital: 21976.01
# Checking V on 2024-11-01: Buy Price = $280.41, Sell Price = $289.22, Gain = +3.1418%
# Checking AMZN on 2024-11-01: Buy Price = $190.83, Sell Price = $197.93, Gain = +3.7206%
# End of week: Forced sell of V at $290.32. Capital: 73732.72
# End of week: Forced sell of AMZN at $195.78. Capital: 125019.42
#
# Processing week 49
# 2024-11-06: Bought SIE.DE. Units: 277.95 at $179.89. Remaining capital: 75019.42
# 2024-11-06: Bought MUV2.DE. Units: 106.27 at $470.50. Remaining capital: 25019.42
# Checking SIE.DE on 2024-11-09: Buy Price = $179.89, Sell Price = $181.59, Gain = +0.9450%
# Checking MUV2.DE on 2024-11-09: Buy Price = $470.50, Sell Price = $478.20, Gain = +1.6366%
# End of week: Forced sell of SIE.DE at $181.59. Capital: 75481.84
# End of week: Forced sell of MUV2.DE at $478.20. Capital: 126289.95
#
# Processing week 50
# 2024-11-12: Bought TSLA. Units: 152.21 at $328.49. Remaining capital: 76289.95
# 2024-11-12: Bought V. Units: 161.91 at $308.82. Remaining capital: 26289.95
# Checking TSLA on 2024-11-15: Buy Price = $328.49, Sell Price = $320.72, Gain = -2.3654%
# Checking V on 2024-11-15: Buy Price = $308.82, Sell Price = $308.61, Gain = -0.0680%
# End of week: Forced sell of TSLA at $338.74. Capital: 77839.81
# End of week: Forced sell of V at $311.12. Capital: 128202.12
#
# Processing week 51
# 2024-11-19: Bought TSLA. Units: 144.51 at $346.00. Remaining capital: 78202.12
# 2024-11-19: Bought IBM. Units: 240.99 at $207.48. Remaining capital: 28202.12
# Checking TSLA on 2024-11-22: Buy Price = $346.00, Sell Price = $352.56, Gain = +1.8960%
# Checking IBM on 2024-11-22: Buy Price = $207.48, Sell Price = $220.03, Gain = +6.0488%
# End of week: Forced sell of TSLA at $338.59. Capital: 77121.53
# End of week: Forced sell of IBM at $223.15. Capital: 130887.04
#
# Processing week 52
# 2024-11-26: Bought AMZN. Units: 240.55 at $207.86. Remaining capital: 80887.04
# 2024-11-26: Bought IBM. Units: 221.43 at $225.81. Remaining capital: 30887.04
# Checking AMZN on 2024-11-29: Buy Price = $207.86, Sell Price = $207.89, Gain = +0.0144%
# Checking IBM on 2024-11-29: Buy Price = $225.81, Sell Price = $224.41, Gain = -0.6200%
# End of week: Forced sell of AMZN at $210.71. Capital: 81562.46
# End of week: Forced sell of IBM at $224.39. Capital: 131238.10
#
# Initial Capital: $100,000.00
# Final Capital $131,238.10
# Capital Increase: +$31,238.10 (+31.24%)
#
# ----------------------------------------------------------------------
# Running Buy and Hold Strategy...
# ----------------------------------------------------------------------
#
# Processing stock: KO
# Bought 180 KO stock units on the first day 2023-11-21 at $55.46.
# Sold 180 KO stock units on the last day 2024-12-03 at $63.05. Final Capital: $11346.73
#
# Processing stock: AMZN
# Bought 69 AMZN stock units on the first day 2023-11-21 at $143.90.
# Sold 69 AMZN stock units on the last day 2024-12-03 at $213.44. Final Capital: $14724.41
#
# Processing stock: IBM
# Bought 68 IBM stock units on the first day 2023-11-21 at $146.58.
# Sold 68 IBM stock units on the last day 2024-12-03 at $225.98. Final Capital: $15363.57
#
# Processing stock: SIE.DE
# Bought 69 SIE.DE stock units on the first day 2023-11-28 at $143.86.
# Sold 69 SIE.DE stock units on the last day 2024-12-03 at $185.85. Final Capital: $12821.09
#
# Processing stock: TSLA
# Bought 41 TSLA stock units on the first day 2023-11-21 at $241.20.
# Sold 41 TSLA stock units on the last day 2024-12-03 at $351.42. Final Capital: $14405.34
#
# Processing stock: VOW3.DE
# Bought 109 VOW3.DE stock units on the first day 2023-11-28 at $91.19.
# Sold 109 VOW3.DE stock units on the last day 2024-12-03 at $75.39. Final Capital: $8215.87
#
# Processing stock: V
# Bought 40 V stock units on the first day 2023-11-21 at $249.48.
# Sold 40 V stock units on the last day 2024-12-03 at $311.97. Final Capital: $12476.30
#
# Processing stock: MUV2.DE
# Bought 26 MUV2.DE stock units on the first day 2023-11-28 at $376.27.
# Sold 26 MUV2.DE stock units on the last day 2024-12-03 at $506.00. Final Capital: $13153.37
#
# Processing stock: BAS.DE
# Bought 264 BAS.DE stock units on the first day 2023-11-28 at $37.84.
# Sold 264 BAS.DE stock units on the last day 2024-12-03 at $41.72. Final Capital: $11011.88
#
# Processing stock: BAYN.DE
# Bought 330 BAYN.DE stock units on the first day 2023-11-28 at $30.29.
# Sold 330 BAYN.DE stock units on the last day 2024-12-03 at $19.14. Final Capital: $6314.94
#
# Initial Capital: $100,000.00
# Final Capital $119,833.49
# Capital Increase: +$19,833.49 (+19.83%)
#
# ----------------------------------------------------------------------
# Running Dow Jones Index Strategy...
# ----------------------------------------------------------------------
#
# Initial Capital: $100,000.00
# Final Capital $127,357.73
# Capital Increase: +$27,357.73 (+27.36%)
#
# ----------------------------------------------------------------------
# Performance Evaluation of Investment Strategies...
# ----------------------------------------------------------------------
#
# Initial Capital: $100,000.00
#
# Trading Bot      Final Capital: $131,238.10  Return: +31.24%
# Buy and Hold     Final Capital: $119,833.49  Return: +19.83%
# Dow Jones Index  Final Capital: $127,357.73  Return: +27.36%
#
# Outperformance:
# Trading Bot      outperformed Buy and Hold    by 11.40%
# Trading Bot      outperformed Dow Jones Index by  3.88%
